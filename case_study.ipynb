# %%
import pandas as pd 
import seaborn as sns

# %%
supplies=pd.read_csv('office_supplies.csv')

# %%
supplies.head()
# Out:
#          Order ID  Order Date    Ship Mode Region       Product ID  \
# 0  CA-2015-110870  2015-12-12  First Class   West  TEC-AC-10002926
# 1  CA-2015-110870  2015-12-12  First Class   West  OFF-SU-10001225
# 2  CA-2014-143210  2014-12-01  First Class   East  TEC-PH-10004434
# 3  CA-2014-143210  2014-12-01  First Class   East  FUR-FU-10003878
# 4  CA-2014-143210  2014-12-01  First Class   East  FUR-FU-10002268
#
#           Category Sub-Category                                 Product Name  \
# 0       Technology  Accessories        Logitech Wireless Marathon Mouse M705
# 1  Office Supplies     Supplies                               Staple remover
# 2       Technology       Phones  Cisco IP Phone 7961G VoIP phone - Dark gray
# 3        Furniture  Furnishings           Linden 10" Round Wall Clock, Black
# 4        Furniture  Furnishings                        Ultra Door Push Plate
#
#     Sales  Quantity  Discount  Profit
# 0  299.94         6       0.0     NaN
# ...

# %%
supplies.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Mode', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit'],
#       dtype='object')

# %%
supplies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      9993 non-null   object
#  1   Order Date    9993 non-null   object
#  2   Ship Mode     9993 non-null   object
#  3   Region        9993 non-null   object
#  4   Product ID    9993 non-null   object
#  5   Category      9993 non-null   object
#  6   Sub-Category  9993 non-null   object
#  7   Product Name  9993 non-null   object
#  8   Sales         9993 non-null   float64
#  9   Quantity      9993 non-null   int64
#  10  Discount      9993 non-null   float64
#  11  Profit        8000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.0+ KB

# %%
sns.boxenplot(x='Category',y='Discount',data=supplies)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Discount'>

# %%
sns.scatterplot(x='Sales',y='Discount',data=supplies,hue='Category')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Discount'>

# %%
supplies_date=supplies['Order Date'].value_counts()

# %%
# Out:
# 2016-09-05    38
# 2017-09-02    36
# 2016-11-10    35
# 2017-12-01    34
# 2017-12-02    34
#               ..
# 2015-04-14     1
# 2014-06-14     1
# 2015-01-28     1
# 2014-01-15     1
# 2016-07-20     1
# Name: Order Date, Length: 1237, dtype: int64

# %%
sns.violinplot(x='Region',y='Profit',data=supplies)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
sns.violinplot(x='Category',y='Sales',data=supplies,hue='Region')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.violinplot(x='Category',y='Quantity',data=supplies,hue='Region')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Quantity'>

# %%
sns.scatterplot(x='Sales',y='Profit',data=supplies)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
sns.scatterplot(x='Discount',y='Profit',data=supplies)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
supplies.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200794 -0.028187  0.414750
# Quantity  0.200794  1.000000  0.008630  0.063334
# Discount -0.028187  0.008630  1.000000 -0.228720
# Profit    0.414750  0.063334 -0.228720  1.000000

# %%
sns.scatterplot(x='Quantity',y='Profit',data=supplies,hue='Discount')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Profit'>

# %%
sns.scatterplot(x='Quantity',y='Sales',data=supplies,hue='Region')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Sales'>

# %%
sns.violinplot(x='Region',y='Quantity',data=supplies,hue='Category')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Quantity'>
